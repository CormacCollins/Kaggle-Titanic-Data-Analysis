# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tabulate
import statistical_tools as s_tools
import statsmodels.api as sm 
from statsmodels.formula.api import glm 
#plotting with seaborn
#https://cmdlinetips.com/2019/02/how-to-make-histogram-in-python-with-pandas-and-seaborn/

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# This time we want to play around with some of the other factors a bit more, now last time I fixed up the missing values in Age, but I just wanted to show the nice technique visually for how to fill in some of this numerical data

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
 def plot_distr(df):
    max_age = max(df['Age'])
    bin_count = np.linspace(0, max_age, (int(max_age/10)+1))
    sns.distplot(df['Age'], bins=bin_count, kde=False, label='all ages');

    plt.legend(prop={'size': 12});
    plt.title('All passengers ages vs survived passengers');
    plt.xlabel('Age groups');
    plt.ylabel('Density');
plot_distr(train)

# %% [markdown]
# This is a distribution plot of the ages, and we have lots of NA values, so we need to fill in the gaps somehow. We could replace them with the mean or median, but this would narrow the distirbution and alter the data. What we will actually do is randomly sample from this dataset within our usually expected range within a std's either side of the mean

# %%
#replace null values with random samples from distr
def resample_age_values(df):
    mean = np.mean(df['Age'])
    std = np.std(df['Age'])

    rand_age = np.random.randint(mean - std, mean + std, size = df['Age'].isnull().sum())
    age_slice = df["Age"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df["Age"] = age_slice
    df["Age"] = df["Age"].astype(int)

resample_age_values(train)
resample_age_values(test)

# %%
#plot again and see how the distribution stays the same but with more values
plot_distr(train)

# %% [markdown]
# You will notice the distribution shape looks identical, except if you look at the y-axis you will see that it has grown taller and relatively equal (of course we may be increasing the rareness of the extreme values a bit more, we could use 2*Stdev instead if we wanted.

# %% [markdown]
# Next we will extract the cabin letters from the tickets, and see if there is any information we can gleam from this

# %%
def cabin_letter(df):
    df['Cabin_letter'] = df['Cabin'].str.replace('\d+', '')
    df['Cabin_letter'] = df['Cabin_letter'].str[0:1]
    m = df['Cabin_letter'].value_counts().idxmax()
    df.loc[df['Cabin_letter'] == 'T', 'Cabin_letter'] = m
cabin_letter(train)
cabin_letter(test)

# %%
#add is_young category
train['is_young'] = np.where(train['Age'] < 11, 1, 0)
test['is_young'] = np.where(test['Age'] < 11, 1, 0)
#categorize family numbers
for letter in train['Embarked'].value_counts().index:
    train['embarked_' + letter] = np.where(train['Embarked']== letter, 1, 0)
    test['embarked_' + letter] = np.where(test['Embarked']== letter, 1, 0)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked Cabin_letter  is_young  \
# 0      0         A/5 21171   7.2500   NaN        S          NaN         0
# 1      0          PC 17599  71.2833   C85        C            C         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S          NaN         0
# 3      0            113803  53.1000  C123        S            C         0
# 4      0            373450   8.0500   NaN        S          NaN         0
#
#    embarked_S  embarked_C  embarked_Q
# 0           1           0           0
# 1           0           1           0
# 2           1           0           0
# 3           1           0           0
# 4           1           0           0

# %%
def plot_surv_category(d, cat):
    prop_survived_parch = d[cat][d['Survived'] == 1].value_counts().sort_index()/d[cat].value_counts().sort_index()
    prop_survived_parch = prop_survived_parch.fillna(0)
    df = pd.DataFrame({'proportion survived': prop_survived_parch,
                         'count': train[cat].value_counts().sort_index().index})


    sns.lineplot(x = 'count', y = 'proportion survived',  data=df, label=' ')
    #sns.distplot(,  kde=False,label='SibSp')
    #plt.ylim(0, 300)

    plt.legend(prop={'size': 12})
    #plt.title('All passengers ages vs survived passengers')
    plt.xlabel('Number of people')

    plt.ylabel('Proportions surviving')
    plt.title('Survival depending on ' + cat)
plot_surv_category(train, 'Cabin_letter')

# %% [markdown]
# Here can see there might be some importance to thos eparticularly cabin numbers, maybe they are easier to escape from, or maybe some of them are richer people too. Either way, we might extract a few of these important cabin numbers and use them as predictors

# %%
for letter in ['B', 'D', 'E']:
    train['cabin_' + letter] = np.where(train['Cabin_letter'] == letter, 1, 0)
    test['cabin_' + letter] = np.where(test['Cabin_letter'] == letter, 1, 0)

# %%
common = train['Embarked'].describe().top
train['Embarked'] = train['Embarked'].fillna(common)
common = test['Embarked'].describe().top
test['Embarked'] = test['Embarked'].fillna(common)

# %%
plot_surv_category(train, 'Embarked')

# %% [markdown]
# Also looking at the embark code, we see some differences in survival, again this might be very well related to class or cabin number, but maybe the ship was filled form the bottom up, so later boarding regions had an advantage? So we can add it to our list and see what it does.

# %%
def set_title_field(df):
    titles = {"Mr": 1, "Miss": 2, 'Mlle':2, 'Ms':2, 'Mme':3, "Mrs": 3, "Master": 4, "Rare": 5, 'Lady': 5, 'Countess':5 ,'Capt': 5, 'Col': 5,'Don': 5, 'Dr': 5,\
                                            'Major': 5, 'Rev': 5, 'Sir': 5, 'Jonkheer': 5, 'Dona': 5}

    df['title'] = 0
    
    title_set = set(titles.keys())
    l = list()
    for i in range(len(df)):
        vals = df['Name'].iloc[i].split(' ') 
        for j in vals:
            title = j.strip('.')
            if title in title_set:
                #print(title)
                df['title'].iloc[i] = titles[title]
                break
            
set_title_field(train)
set_title_field(test)
train['title'].value_counts()
# Out:
# 1    517
# 2    185
# 3    126
# 4     40
# 5     23
# Name: title, dtype: int64

# %% [markdown]
# I am also seen form other peoples analysis of this data set the use of 'title', so I have extracted that and will use it.
# I looked at how that was done here: https://towardsdatascience.com/predicting-the-survival-of-titanic-passengers-30870ccc7e8

# %%
titles
# Out:
# {'Mr': 1,
#  'Miss': 2,
#  'Mlle': 2,
#  'Ms': 2,
#  'Mme': 3,
#  'Mrs': 3,
#  'Master': 4,
#  'Rare': 5,
#  'Lady': 5,
#  'Countess': 5,
#  'Capt': 5,
#  'Col': 5,
#  'Don': 5,
#  'Dr': 5,
#  'Major': 5,
#  'Rev': 5,
#  'Sir': 5,
#  'Jonkheer': 5,
#  'Dona': 5}

# %%
ax = sns.barplot(x="title", y="Survived", data=train);
plt.title('Proportion of survival by title');

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare  ... Embarked Cabin_letter is_young  \
# 0      0         A/5 21171   7.2500  ...        S          NaN        0
# 1      0          PC 17599  71.2833  ...        C            C        0
# 2      0  STON/O2. 3101282   7.9250  ...        S          NaN        0
# 3      0            113803  53.1000  ...        S            C        0
# 4      0            373450   8.0500  ...        S          NaN        0
#
#    embarked_S  embarked_C  embarked_Q  cabin_B  cabin_D  cabin_E  title
# 0           1           0           0        0        0        0      1
# 1           0           1           0        0        0        0      3
# 2           1           0           0        0        0        0      2
# 3           1           0           0        0        0        0      3
# 4           1           0           0        0        0        0      1
#
# [5 rows x 21 columns]

# %% [markdown]
# So now we can see some of the new fields I have created for the categories, to allow the logistical model to intepret them

# %%
#VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor 

# Get variables for which to compute VIF and add intercept term 
#Pclass == 1 and Sex == male are the reference factors for those categories - it is redundant to put them in and actually causes errors

factors_arr = ['is_young', 'embarked_C' , 'Parch', 'SibSp', 'Fare', 'cabin_B', 'cabin_D', 'cabin_E', 'title']



X = train[factors_arr].copy()
X['class 2'] = np.where(train['Pclass']== 2, 1, 0)
X['class 3'] = np.where(train['Pclass']== 3, 1, 0)
X['F'] = np.where(train['Sex']== 'female', 1, 0)
X['Intercept'] = 1 

factors_arr.append('Pclass')
factors_arr.append('Sex')

# Compute and view VIF 
vif = pd.DataFrame() 
vif["variables"] = X.columns 

vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])] 

  

# View results using print 

print(vif)
# Out:
#      variables        VIF
# 0     is_young   1.348292
# 1   embarked_C   1.137017
# 2        Parch   1.423888
# 3        SibSp   1.353032
# 4         Fare   1.870022
# 5      cabin_B   1.357221
# 6      cabin_D   1.184625
# 7      cabin_E   1.145763
# 8        title   1.675813
# 9      class 2   2.432940
# 10     class 3   3.271180
# 11           F   1.427748
# 12   Intercept  16.617555

# %% [markdown]
# Calculating the VIF we don't see anything except class 3 over the 2.5 threshold, so that looks pretty good. Although I will still take this with a grain of salt, given VIF's use with categorical is not as strong.

# %% [markdown]
# Next I'm going to play around with the amount of training data to verification ratio that I use, so I'm not only going to calculate a range of models based on different ratio's. But I'm then going to test them for the optimal threshold value again, same as last time.

# %%
#data_slice = np.random.choice(len(train), replace=False, size=10)
#train[train.index.isin(data_slice)]

# %%
#find optimized threshold for model

def get_optimal_threshold(pred, df2):
    n = 40 
    thresholds = list()
    prop_corr = list()
    #print(len(df2))
    for i in np.linspace(0.0, 1, n):
        predicted_survive = (pred >= i)
        num_correct = (predicted_survive.astype(bool)) == (df2['Survived'].astype(bool))
        s = pd.DataFrame({'pred': predicted_survive,
                      'surv': df2['Survived'],
                         'AND': num_correct})
        #print(s[0:20])
        #break
        #l.append([i, sum(num_correct)])
        thresholds.append(i)
        prop_corr.append(sum(num_correct))

    df = pd.DataFrame({'threshold': thresholds, 'proportion correct':prop_corr})
    m = df['proportion correct'].idxmax()
    pr = df['threshold'].iloc[m]   
    return 'Best threshold: {:04.2f}\n'.format(pr) + 'Predictions correct: {}/{} == {:04.2f}'.format(df['proportion correct'].max(), len(df2), df['proportion correct'].max()/ len(df2))




# Define model formula 

data_split_ranges = np.linspace(int(len(train)/2), int(len(train)-50), 30, dtype = int)



list_glms = list()
l = list()
for i in data_split_ranges:
    
    #get random rows
    data_slice = np.random.choice(len(train), replace=False, size=i)
    train_half = train[train.index.isin(data_slice)].copy()
    train_2nd_half = train[~train.index.isin(data_slice)].copy()
    
    formula = 'Survived ~ is_young + SibSp + Parch + C(Pclass) + C(Sex) + embarked_C + cabin_B + cabin_D + cabin_E + C(title)' # + C(Cabin_letter)' 
    model = glm(formula, data = train_half, family = sm.families.Binomial()).fit() 
    #print(model.summary()) 
    pred_glm = model.predict(train_2nd_half) 
    #list_glms.append(pred_glm)
    #train_2nd_half['expected_survive'] = pred_glm
    txt = get_optimal_threshold(pred_glm, train_2nd_half)
    l.append('testing data with {:02.2f}%\n'.format(i/len(train)*100 ) +txt)

    
[print(i) for i in l]
# Out:
# testing data with 49.94%
# Best threshold: 0.59
# Predictions correct: 369/446 == 0.83
# testing data with 51.40%
# Best threshold: 0.51
# Predictions correct: 365/433 == 0.84
# testing data with 52.97%
# Best threshold: 0.69
# Predictions correct: 347/419 == 0.83
# testing data with 54.43%
# Best threshold: 0.59
# Predictions correct: 339/406 == 0.83
# testing data with 56.00%
# Best threshold: 0.54
# Predictions correct: 329/392 == 0.84
# testing data with 57.58%
# Best threshold: 0.49
# Predictions correct: 300/378 == 0.79
# testing data with 59.03%
# Best threshold: 0.62
# Predictions correct: 301/365 == 0.82
# testing data with 60.61%
# Best threshold: 0.56
# Predictions correct: 298/351 == 0.85
# testing data with 62.18%
# Best threshold: 0.51
# Predictions correct: 275/337 == 0.82
# testing data with 63.64%
# Best threshold: 0.64
# Predictions correct: 267/324 == 0.82
# testing data with 65.21%
# Best threshold: 0.51
# Predictions correct: 261/310 == 0.84
# testing data with 66.78%
# Best threshold: 0.59
# Predictions correct: 250/296 == 0.84
# testing data with 68.24%
# Best threshold: 0.46
# Predictions correct: 237/283 == 0.84
# testing data with 69.81%
# Best threshold: 0.59
# Predictions correct: 222/269 == 0.83
# testing data with 71.38%
# Best threshold: 0.46
# Predictions correct: 215/255 == 0.84
# testing data with 72.84%
# Best threshold: 0.49
# Predictions correct: 194/242 == 0.80
# testing data with 74.41%
# Best threshold: 0.54
# Predictions correct: 195/228 == 0.86
# testing data with 75.98%
# Best threshold: 0.54
# Predictions correct: 176/214 == 0.82
# testing data with 77.44%
# Best threshold: 0.54
# Predictions correct: 171/201 == 0.85
# testing data with 79.01%
# Best threshold: 0.59
# Predictions correct: 151/187 == 0.81
# testing data with 80.58%
# Best threshold: 0.59
# Predictions correct: 146/173 == 0.84
# testing data with 82.04%
# Best threshold: 0.33
# Predictions correct: 137/160 == 0.86
# testing data with 83.61%
# Best threshold: 0.56
# Predictions correct: 122/146 == 0.84
# testing data with 85.19%
# Best threshold: 0.69
# Predictions correct: 119/132 == 0.90
# testing data with 86.64%
# Best threshold: 0.54
# Predictions correct: 103/119 == 0.87
# testing data with 88.22%
# Best threshold: 0.49
# Predictions correct: 84/105 == 0.80
# testing data with 89.79%
# Best threshold: 0.54
# Predictions correct: 78/91 == 0.86
# testing data with 91.25%
# Best threshold: 0.51
# Predictions correct: 65/78 == 0.83
# testing data with 92.82%
# Best threshold: 0.36
# Predictions correct: 53/64 == 0.83
# testing data with 94.39%
# Best threshold: 0.62
# Predictions correct: 39/50 == 0.78
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# We see an interesting trade off here, while my accuracy appears to be improving as I train the model on more data, we can see that it's also harder to be confident in it's predictive power due to the limited sample to test it on after training. But we are getting some good predictions using large amounts of training data

# %% [markdown]
# Given that the threshold does tend to work best around 50%, we wil stick with that. And instead, see how our model fairs on predicting with the kaggle testing, when varying how much of data we train our model with, of course we should expect a better result if we can train the model with more data.

# %%
run_query_to_kaggle = False


if True:

    import subprocess
    query = 'kaggle competitions submit -c titanic -f submission_2.csv -m "Message"'.split(' ')
    output = list()
    for i in range(7, 10):

        data_slice = np.random.choice(len(train), replace=False, size=int(len(train)*(i/10)))
        train_half = train[train.index.isin(data_slice)].copy()
        train_2nd_half = train[~train.index.isin(data_slice)].copy()

        formula = 'Survived ~ is_young + SibSp + Parch + C(Pclass) + C(Sex) + embarked_C + cabin_B + cabin_D + cabin_E + C(title)' # + C(Cabin_letter)' 
        model = glm(formula, data = train_half, family = sm.families.Binomial()).fit() 

        pred_glm = model.predict(test) 
        predicted_survive = (pred_glm >= 0.50)
        test['Survived'] = predicted_survive.astype(int)
        test_file = test[['PassengerId', 'Survived']]
        test_file.to_csv('submission_2.csv', header=True, index=False)

        try:
            print('Trying with ' + str(len(train)*(i/10)))
            output.append(subprocess.check_output(query))
        except:
            print('failed')

    output

# %%
[0.75119, 0.77511, 0.77511,0.77990, 0.78468]
# Out:
# [0.75119, 0.77511, 0.77511, 0.7799, 0.78468]
